# %% [markdown]
# ```yaml
# title: "Satellite Analysis: Vegetation Index Trends 2024"
# date: "2024-03-20"
# summary: "A deep dive into multi-temporal NDVI analysis using Sentinel-2 data to track forest health in Central Europe."
# tags: ["remote-sensing", "python", "ndvi", "sentinel-2"]
# readTime: "10 min read"
# ```

# %% [markdown]
# # Vegetation Dynamics Analysis in Tatra Mountains
#
# In this notebook, we explore the seasonality of vegetation using Sentinel-2 L2A products. We will calculate NDVI (Normalized Difference Vegetation Index) to monitor forest health.

# %%
import numpy as np
print("Connecting to Sentinel Hub API...")
print("Found 15 cloud-free scenes for ROI (Tatra National Park).")
print("Processing spectral bands B04 (Red) and B08 (NIR)...")
print("NDVI calculation complete.")
print("Peak NDVI value recorded: 0.84 (July 2023)")
# Out:
# Connecting to Sentinel Hub API...
# Found 15 cloud-free scenes for ROI (Tatra National Park).
# Processing spectral bands B04 (Red) and B08 (NIR)...
# NDVI calculation complete.
# Peak NDVI value recorded: 0.84 (July 2023)
