# %% [markdown]
# ---
# title: Welcome to Geospatial Engineering
# date: 2026-03-06
# summary: An introduction to satellite data analysis and the GeoWorldLook platform pipeline.
# tags: [Introduction, Python, Sentinel-2]
# readTime: 5 min
# ---

# %% [markdown]
# # Analyzing Earth from Space
#
# In this notebook, we explore how satellite imagery can be processed to monitor environmental changes. We use Sentinel-2 multispectral data to calculate NDVI (Normalized Difference Vegetation Index).

# %%
import numpy as np

def calculate_ndvi(nir, red):
    return (nir - red) / (nir + red)

print("Loading spectral bands...")
print("Calculating NDVI for Mazovia region...")
print("Analysis complete.")
# Out:
# Loading spectral bands...
# Calculating NDVI for Mazovia region...
# Analysis complete.
