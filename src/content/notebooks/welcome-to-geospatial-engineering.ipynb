# %% [markdown]
# ---
# title: Welcome to Geospatial Engineering
# date: 2026-03-01
# summary: An introduction to satellite data analysis and automated pipelines using Google Colab and Next.js.
# tags: [Introduction, Sentinel-2, Python]
# readTime: 3 min read
# ---

# %% [markdown]
# # Mastering Satellite Intelligence
#
# Geospatial engineering is no longer just about maps; it's about building automated systems that process orbital data into actionable insights. In this article, we'll explore how we use Sentinel-2 imagery to monitor terrestrial changes.

# %%
import numpy as np

def calculate_ndvi(red, nir):
    return (nir - red) / (nir + red)

print("Initializing Geospatial Engine...")
print("Sentinel-2 Hub Connected.")
print("Processing Area: 52.2297° N, 21.0122° E (Warsaw)")
# Out:
# Initializing Geospatial Engine...
# Sentinel-2 Hub Connected.
# Processing Area: 52.2297° N, 21.0122° E (Warsaw)

# %% [markdown]
# ## NDVI Visualization
#
# The Normalized Difference Vegetation Index (NDVI) is a simple graphical indicator that can be used to analyze remote sensing measurements.
