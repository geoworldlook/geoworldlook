# %% [markdown]
# ```yaml
# title: "Introduction to Geospatial Data Engineering with Python"
# date: "2025-03-01"
# summary: "A deep dive into how we use GeoPandas and Rasterio to process Sentinel-2 data at scale."
# tags: ["Python", "Remote Sensing", "Data Engineering"]
# readTime: "12 min read"
# ```

# %% [markdown]
# # Welcome to Geospatial Engineering
#
# This post is a demonstration of our **Colab-to-Blog** pipeline. It renders raw `.ipynb` cells directly on the server.

# %%
import geopandas as gpd
print(f"GeoPandas version: {gpd.__version__}")
print("Processing multispectral imagery...")
# Out:
# GeoPandas version: 0.14.0
# Processing multispectral imagery...
